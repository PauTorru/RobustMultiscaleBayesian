# %%
import RMB.RMB as RMB
import espm

# %%
s = hs.load("sample_0.hspy")
s.change_dtype("float")

# %%
s.plot()

# %%
#s.add_elements(['Cu', 'La', 'V', 'O']) # add elements if necessary
s.metadata.Sample.elements
# Out:
# ['Cu', 'La', 'V', 'O']

# %%
s.set_signal_type("EDS_espm")
s.set_additional_parameters() # espm setup

# %%
s.build_G() # Generates endmembers for each element and Bremsstrahlung background

# %%
# For a multiscale contruct consisting of : Original data, 3x3-averaged, 5x5 averaged, we use:
Maps, Variances = RMB.get_RMB_maps(s,[1,3,5])
# Out:
# Generating multiscale
# Done
# Calculating Neighbours
# Done
# BMS calculation
# 1 / 6
# 2 / 6
# 3 / 6
# 4 / 6
# 5 / 6
# 6 / 6

# %%
print(Maps.shape)
print(Variances.shape)
# Last two images correspond Bremsstrahlung background estimation
# to obtain atomic % divide by maps[:-2].sum(-1)
# Out:
# (64, 64, 6)
# (64, 64, 6)

# %%
plt.clf()

for i in range(4):
    el = s.metadata.Sample.elements[i]
    ax = plt.subplot(2,4,i+1)
    plt.imshow(Maps[...,i])
    ax.set_title("Abundance of {}".format(el))

    ax2 = plt.subplot(2,4,5+i)
    plt.imshow(Variances[...,i])
    ax2.set_title("uncertainty of {}".format(el))

plt.tight_layout()

# %%
#lets check if our model is reasonable:
model = RMB.build_RMB_model(s,Maps,s.G())
model.plot()

# %%
# A useful way to compare to the original dataset:
hs.signals.Signal1D(model.data+1j*s.data).plot()

# %%
plt.clf()

plt.plot(s.axes_manager[-1].axis,model.data.sum((0,1)),label = "Model, sum of all pixel")
plt.plot(s.axes_manager[-1].axis,s.data.sum((0,1)),label = "Data, sum of all pixels")

plt.legend()

# %%
# To obtained maps of atomic % and the corresponding quantification error:

Quant_Maps, Quant_error = RMB.atomic_percentage_and_uncertainty_from_RMB_maps(Maps,Variances)

plt.clf()

for i in range(4):
    el = s.metadata.Sample.elements[i]
    ax = plt.subplot(2,4,i+1)
    plt.imshow(Quant_Maps[...,i])
    #ax.set_title("at. % of {}".format(el))
    cb1 = plt.colorbar()
    cb1.set_label("% of {}".format(el))

    ax2 = plt.subplot(2,4,5+i)
    plt.imshow(Quant_error[...,i])
    #ax2.set_title("Quantification standard error for {}".format(el))
    cb2 = plt.colorbar()
    cb2.set_label("Standard error of {} %".format(el))

plt.tight_layout()
